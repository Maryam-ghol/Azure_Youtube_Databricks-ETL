# %%
# %pip install google-api-python-client --quiet
dbutils.library.restartPython()

# %%
from googleapiclient.discovery import build

api_key = dbutils.secrets.get(scope="youtube-scope", key="youtube-api-key")

youtube = build("youtube", "v3", developerKey=api_key)

print("YouTube client ready")

# %%
response = youtube.videos().list(
    part="snippet,statistics,contentDetails,status,player,topicDetails,localizations,liveStreamingDetails",
    id="ctVV322aLIU"
).execute()

print(response)
